# %%
import pandas as pd

file_path = 'dim_match_summary.csv'

# Load the CSV file into a DataFrame
df_match = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df_match.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#       match_id
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
df_match.shape
# Out:
# (41, 7)

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   team1      41 non-null     object
#  1   team2      41 non-null     object
#  2   winner     41 non-null     object
#  3   margin     41 non-null     object
#  4   ground     41 non-null     object
#  5   matchDate  41 non-null     object
#  6   match_id   41 non-null     object
# dtypes: object(7)
# memory usage: 2.4+ KB

# %% [markdown]
# Margin column has 41 non-null values, which means there are 4 rows in this column with null values. Let's check

# %%
df_match.isnull().sum()
# Out:
# team1        0
# team2        0
# winner       0
# margin       0
# ground       0
# matchDate    0
# match_id     0
# dtype: int64

# %%
df_match[df_match.margin.isnull()]
# Out:
# Empty DataFrame
# Columns: [team1, team2, winner, margin, ground, matchDate, match_id]
# Index: []

# %% [markdown]
# we can see that 4 matches were abandoned, so we won't have data for these matches and hence we can delete these. We will create a new dataframe without these 4 columns.

# %%
df_match1 = df_match[~df_match.margin.isnull()]

# %%
df_match1.shape
# Out:
# (41, 7)

# %%
df_match.to_csv('t20_csv_files/dim_match_summary.csv', index = False)

# %% [markdown]
# We will create a match ids dictionary that maps team names to a unique match id. This will be useful later on to link with other tables

# %%
match_ids_dict = {}

for index, row in df_match1.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']
    match_ids_dict[key1] = row['match_id']
    match_ids_dict[key2] = row['match_id']

# %%
match_ids_dict
# Out:
# {'Namibia Vs Sri Lanka': 'T20I # 1823',
#  'Sri Lanka Vs Namibia': 'T20I # 1823',
#  'Netherlands Vs U.A.E.': 'T20I # 1825',
#  'U.A.E. Vs Netherlands': 'T20I # 1825',
#  'Scotland Vs West Indies': 'T20I # 1826',
#  'West Indies Vs Scotland': 'T20I # 1826',
#  'Ireland Vs Zimbabwe': 'T20I # 1828',
#  'Zimbabwe Vs Ireland': 'T20I # 1828',
#  'Namibia Vs Netherlands': 'T20I # 1830',
#  'Netherlands Vs Namibia': 'T20I # 1830',
#  'Sri Lanka Vs U.A.E.': 'T20I # 1832',
#  'U.A.E. Vs Sri Lanka': 'T20I # 1832',
#  'Ireland Vs Scotland': 'T20I # 1833',
#  'Scotland Vs Ireland': 'T20I # 1833',
#  'West Indies Vs Zimbabwe': 'T20I # 1834',
#  'Zimbabwe Vs West Indies': 'T20I # 1834',
#  'Bangladesh Vs Pakistan': 'T20I # 1872',
#  'Pakistan Vs Bangladesh': 'T20I # 1872',
#  'India Vs Zimbabwe': 'T20I # 1873',
#  'Zimbabwe Vs India': 'T20I # 1873',
#  'New Zealand Vs Pakistan': 'T20I # 1877',
#  'Pakistan Vs New Zealand': 'T20I # 1877',
#  'England Vs India': 'T20I # 1878',
#  'India Vs England': 'T20I # 1878',
#  'England Vs Pakistan': 'T20I # 1879',
#  'Pakistan Vs England': 'T20I # 1879'}

# %% [markdown]
# We have processed the match_summary table and created new csv file 'df_match1'.
# #### Let's now work on Batting Summary table

# %%
df_batting = pd.read_csv('fact_bating_summary.csv')

# Display the first few rows of the DataFrame
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)    20
#
#    balls  4s  6s      SR out/not_out
# 0      6   0   0      50         out
# 1      9   1   0     100         out
# 2     12   1   2  166.66         out
# 3     24   2   0  108.33         out
# 4     24   0   0   83.33         out

# %%
df_batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        699 non-null    object
#  1   teamInnings  699 non-null    object
#  2   battingPos   699 non-null    int64
#  3   batsmanName  699 non-null    object
#  4   runs         699 non-null    int64
#  5   balls        699 non-null    int64
#  6   4s           699 non-null    int64
#  7   6s           699 non-null    int64
#  8   SR           699 non-null    object
#  9   out/not_out  699 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 54.7+ KB

# %%
df_batting.isnull().sum()
# Out:
# match          0
# teamInnings    0
# battingPos     0
# batsmanName    0
# runs           0
# balls          0
# 4s             0
# 6s             0
# SR             0
# out/not_out    0
# dtype: int64

# %% [markdown]
# There doesn't seem to be any null values. So, we can move ahead

# %% [markdown]
# Let's map the matchid to this table

# %%
df_batting['match_id'] = df_batting['match'].map(match_ids_dict)
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)    20
#
#    balls  4s  6s      SR out/not_out     match_id
# 0      6   0   0      50         out  T20I # 1823
# 1      9   1   0     100         out  T20I # 1823
# 2     12   1   2  166.66         out  T20I # 1823
# 3     24   2   0  108.33         out  T20I # 1823
# 4     24   0   0   83.33         out  T20I # 1823

# %%
df_batting.to_csv('t20_csv_files/fact_bating_summary.csv', index = False)

# %% [markdown]
# Let's now work on the bowling data

# %%
df_bowling = pd.read_csv('fact_bowling_summary.csv')
df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName  overs  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana    4.0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera    4.0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan    4.0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne    4.0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva    4.0
#
#    maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls     match_id
# 0       0    23        1     5.75   7   0   0      2        0  T20I # 1823
# 1       0    39        1     9.75   6   3   1      2        0  T20I # 1823
# 2       0    37        2     9.25   6   3   1      0        0  T20I # 1823
# 3       0    36        1     9.00   7   3   1      1        0  T20I # 1823
# 4       0    27        1     6.75   8   1   1      0        0  T20I # 1823

# %%
df_bowling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        500 non-null    object
#  1   bowlingTeam  500 non-null    object
#  2   bowlerName   500 non-null    object
#  3   overs        500 non-null    float64
#  4   maiden       500 non-null    int64
#  5   runs         500 non-null    int64
#  6   wickets      500 non-null    int64
#  7   economy      500 non-null    float64
#  8   0s           500 non-null    int64
#  9   4s           500 non-null    int64
#  10  6s           500 non-null    int64
#  11  wides        500 non-null    int64
#  12  noBalls      500 non-null    int64
#  13  match_id     500 non-null    object
# dtypes: float64(2), int64(8), object(4)
# memory usage: 54.8+ KB

# %% [markdown]
# There's no null values. So, lets move ahead

# %% [markdown]
# Let's now work on player information data

# %%
df_players = pd.read_csv('dim_players.csv')
df_players.head()
# Out:
#                     name        team image    battingStyle  \
# 0  Najmul Hossain Shanto  Bangladesh   NaN   Left hand Bat
# 1          Soumya Sarkar  Bangladesh   NaN   Left hand Bat
# 2             Litton Das  Bangladesh   NaN  Right hand Bat
# 3     Shakib Al Hasan(c)  Bangladesh   NaN   Left hand Bat
# 4           Afif Hossain  Bangladesh   NaN   Left hand Bat
#
#              bowlingStyle          playingRole  \
# 0      Right arm Offbreak     Top order Batter
# 1   Right arm Medium fast  Middle order Batter
# 2                     NaN  Wicketkeeper Batter
# 3  Slow Left arm Orthodox           Allrounder
# 4      Right arm Offbreak           Allrounder
#
#                                          description
# 0  Nazmul Hossain Shanto emerged from an unusual ...
# 1  A rarity among Bangladesh allrounders, top-ord...
# 2  Liton Das is the first wicketkeeper-batsman in...
# 3  When the annals of Bangladesh cricket are sift...
# 4  Bangladesh left-hander Afif Hossain made his T...

# %%
df_players.isnull().sum()
# Out:
# name              0
# team              0
# image           188
# battingStyle      0
# bowlingStyle     20
# playingRole       0
# description      70
# dtype: int64

# %%
df_players[df_players.bowlingStyle.isnull()]
# Out:
#                    name          team  \
# 2            Litton Das    Bangladesh
# 6           Nurul Hasan    Bangladesh
# 24      Mohammad Rizwan      Pakistan
# 36   Rahmanullah Gurbaz   Afghanistan
# 37          Usman Ghani   Afghanistan
# 45      Pathum Nissanka     Sri Lanka
# 62      Vriitya Aravind        U.A.E.
# 74     Scott Edwards(c)   Netherlands
# 83        Lorcan Tucker       Ireland
# 92       Jos Buttler(c)       England
# 104     Quinton de Kock  South Africa
# 117       Matthew Cross      Scotland
# 152          Evin Lewis   West Indies
# 153        Brandon King   West Indies
# 164          Finn Allen   New Zealand
# 176          Haider Ali      Pakistan
# 178            KL Rahul         India
# 190     Johnson Charles   West Indies
# 194        Rishabh Pant         India
# 209          Zane Green       Namibia
#
#                                                  image    battingStyle  \
# 2                                                  NaN  Right hand Bat
# 6                                                  NaN  Right hand Bat
# 24                                                 NaN  Right hand Bat
# 36                                                 NaN  Right hand Bat
# 37                                                 NaN  Right hand Bat
# 45                                                 NaN  Right hand Bat
# 62                                                 NaN  Right hand Bat
# 74                                                 NaN  Right hand Bat
# 83   https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 92   https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 104  https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 117                                                NaN  Right hand Bat
# 152                                                NaN   Left hand Bat
# 153                                                NaN  Right hand Bat
# 164                                                NaN  Right hand Bat
# 176                                                NaN  Right hand Bat
# 178                                                NaN  Right hand Bat
# 190                                                NaN  Right hand Bat
# 194                                                NaN   Left hand Bat
# 209                                                NaN   Left hand Bat
#
#     bowlingStyle          playingRole  \
# 2            NaN  Wicketkeeper Batter
# 6            NaN  Wicketkeeper Batter
# 24           NaN  Wicketkeeper Batter
# 36           NaN  Wicketkeeper Batter
# 37           NaN       Opening Batter
# 45           NaN     Top order Batter
# 62           NaN         Wicketkeeper
# 74           NaN  Wicketkeeper Batter
# 83           NaN  Wicketkeeper Batter
# 92           NaN  Wicketkeeper Batter
# 104          NaN  Wicketkeeper Batter
# 117          NaN  Wicketkeeper Batter
# 152          NaN       Opening Batter
# 153          NaN     Top order Batter
# 164          NaN     Top order Batter
# 176          NaN  Middle order Batter
# 178          NaN       Opening Batter
# 190          NaN  Wicketkeeper Batter
# 194          NaN  Wicketkeeper Batter
# 209          NaN  Wicketkeeper Batter
#
#                                            description
# 2    Liton Das is the first wicketkeeper-batsman in...
# 6    Nurul Hasan, who made his first-class debut in...
# 24   For several years, it appeared Mohammad Rizwan...
# 36                                                 NaN
# 37   One of the most exciting new talents to emerge...
# 45                                                 NaN
# 62                                                 NaN
# 74                                                 NaN
# 83                                                 NaN
# 92   England have had many players down the ages wh...
# 104  Quinton de Kock's fearless striking and handy ...
# 117  A wicketkeeper-batsman from Aberdeen, Matthew ...
# 152  "I hit a lot of sixes, big sixes like him," Ev...
# 153  Brandon King got his start as a solid middle-o...
# 164                                                NaN
# 176                                                NaN
# 178  A tall, elegant right-hand batsman who can kee...
# 190  A muscular opener with a penchant for swatting...
# 194  A match-turning, swashbuckling batter-keeper i...
# 209                                                NaN

# %% [markdown]
# We can see that there are some null values in bowlingStyle column. However, a lot of those missing values are
# for wicketkeepers or opening batters who don't bowl. So, it's fine, we can go ahead with our process
